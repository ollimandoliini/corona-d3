# %%
import os
from json import load, dump

# %%
os.listdir()
# Out:
# ['octave-workspace',
#  'Untitled1.ipynb',
#  'sairaanhoitopiirit.json',
#  'Untitled.ipynb',
#  'municipalities.json',
#  'shp_jäsenkunnat.xls',
#  '.ipynb_checkpoints']

# %%
with open('sairaanhoitopiirit.json') as shp_file, open('municipalities.json') as m_file:
    shp = load(shp_file)
    munic = load(m_file)

# %%
def get_municipality_geo(name):
    for i in munic:
        if i['properties']['Name'].lower() == name.lower():
            return i['geometry']['type'], i['geometry']['coordinates']
    return []

# %%
def get_shp(municipality):
    found = next(filter(lambda x: x['kunta'] == municipality, shp), None)
    if found:
        return found['shp']

# %%
for m in munic['features']:
    municipality_name = m['properties']['Name']
    m['properties']['healthCareDistrict'] = get_shp(municipality_name)

# %%
with open('municipalities.json', 'w') as f:
    dump(munic, f)

# %%
districts = {i['properties']['Name']: i['properties']['healthCareDistrict'] for i in munic['features']}

# %%
with open('municipalities_and_districts.json', 'w') as f:
    dump(districts, f)

# %%
districts['Koski Tl'] = 'Varsinais-Suomi'
districts['Valtimo'] = 'Pohjois-Karjala'
districts['Pedersören kunta'] = 'Vaasa'
ahvenanmaa = """Geta
Vårdö
Lemland
Kumlinge
Maarianhamina
Föglö
Kökar
Finström
Sund
Saltvik
Hammarland
Lumparland
Jomala
Brändö
Sottunga
Eckerö""".split()
for i in ahvenanmaa:
    districts[i] = 'Ahvenanmaa'

# %%
districtnames = set(districts.values())

# %%
districtnames
# Out:
# {'Ahvenanmaa',
#  'Etelä-Karjala',
#  'Etelä-Pohjanmaa',
#  'Etelä-Savo',
#  'HUS',
#  'Itä-Savo',
#  'Kainuu',
#  'Kanta-Häme',
#  'Keski-Pohjanmaa',
#  'Keski-Suomi',
#  'Kymenlaakso',
#  'Lappi',
#  'Länsi-Pohja',
#  'Pirkanmaa',
#  'Pohjois-Karjala',
#  'Pohjois-Pohjanmaa',
#  'Pohjois-Savo',
#  'Päijät-Häme',
#  'Satakunta',
#  'Vaasa',
#  'Varsinais-Suomi'}

# %%
districtnames.add('Ahvenanmaa')

# %%
geo = {
  "type": "FeatureCollection",
  "crs": {
    "type": "name",
    "properties": { "name": "urn:ogc:def:crs:OGC:1.3:CRS84" }
  },
  "features": []
}

# %%
for i in districtnames:
    feat = {'type': 'Feature', 'properties': {
            'Name': i,
            'timestamp': None,
            'begin': None,
            'end': None,
            'altitudeMode': None,
            'tessellate': -1,
            'extrude': 0,
            'visibility': -1,
            'drawOrder': None,
            'icon': None,
            'snippet': ''},
         'geometry': {
             'type': 'MultiPolygon',
             'coordinates': []}}
    geo['features'].append(feat)

# %%
from collections import defaultdict
d = defaultdict(list)

#{'type': 'Feature', 'properties': {'Name': 'Espoo', 'timestamp': None, 'begin': None, 'end': None, 'altitudeMode': None, 'tessellate': -1, 'extrude': 0, 'visibility': -1, 'drawOrder': None, 'icon': None, 'snippet': '', 'healthCareDistrict': 'HUS'}, 'geometry': {'type': 'MultiPolygon', 'coordinates': []}},
for i in munic['features']:
    type_ = i['geometry']['type']
    coords = i['geometry']['coordinates']
    shp = districts.get(i['properties']['Name'])
    if shp is None:
        print(i['properties']['Name'])
    for d in geo['features']:
        if d['properties']['Name'] == shp:
            if type_ == 'Polygon':
                d['geometry']['coordinates'].append(coords)
            elif type_ == 'MultiPolygon':
                for c in coords:
                    d['geometry']['coordinates'].append(c)

# %%
with open('../src/sairaanhoitopiirit_geo.json', 'w') as f:
    dump(geo, f)

# %%
# import necessary packages to work with spatial data in Python
import os
import numpy as np
import geopandas as gpd
import matplotlib.pyplot as plt
import matplotlib.lines as mlines
from matplotlib.colors import ListedColormap

# %%
df = gpd.read_file('../src/sairaanhoitopiirit_geo.json')

# %%
# create the plot
fig, ax = plt.subplots(figsize = (12,8))

# plot the data using a quantile map of the new ALAND values
df.plot(edgecolor = "black",
                 scheme='quantiles', cmap='YlOrRd', ax=ax, 
                 legend = True)

df.dissolve()

# Set plot axis to equal ratio
ax.set_axis_off()
plt.axis('equal');
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-177-4a594c086733> in <module>
#       7                  legend = True)
#       8
# ----> 9 df.dissolve()
#      10
#      11 # Set plot axis to equal ratio
#
# ~/datascience/.venv/lib/python3.7/site-packages/geopandas/geodataframe.py in dissolve(self, by, aggfunc, as_index)
#     684         # Process non-spatial component
#     685         data = self.drop(labels=self.geometry.name, axis=1)
# --> 686         aggregated_data = data.groupby(by=by).agg(aggfunc)
#     687
#     688         # Process spatial component
#
# ~/datascience/.venv/lib/python3.7/site-packages/pandas/core/frame.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed)
#    5796
#    5797         if level is None and by is None:
# -> 5798             raise TypeError("You have to supply one of 'by' and 'level'")
#    5799         axis = self._get_axis_number(axis)
#    5800
#
# TypeError: You have to supply one of 'by' and 'level'

# %%
df['district'] = df['Name'].map(lambda x: districts.get(x))

# %%
df
# Out:
#                    Name                                        description  \
# 0            Nousiainen  <div class="googft-info-window">\n<b>name:</b>...
# 1                Oripää  <div class="googft-info-window">\n<b>name:</b>...
# 2                 Espoo  <div class="googft-info-window">\n<b>name:</b>...
# 3               Tuusula  <div class="googft-info-window">\n<b>name:</b>...
# 4                Muonio  <div class="googft-info-window">\n<b>name:</b>...
# ..                  ...                                                ...
# 306             Heinola  <div class="googft-info-window">\n<b>name:</b>...
# 307  Kristiinankaupunki  <div class="googft-info-window">\n<b>name:</b>...
# 308            Alajärvi  <div class="googft-info-window">\n<b>name:</b>...
# 309               Lapua  <div class="googft-info-window">\n<b>name:</b>...
# 310              Karvia  <div class="googft-info-window">\n<b>name:</b>...
#
#     timestamp begin   end altitudeMode  tessellate  extrude  visibility  \
# 0        None  None  None         None          -1        0          -1
# 1        None  None  None         None          -1        0          -1
# 2        None  None  None         None          -1        0          -1
# 3        None  None  None         None          -1        0          -1
# 4        None  None  None         None          -1        0          -1
# ..        ...   ...   ...          ...         ...      ...         ...
# 306      None  None  None         None          -1        0          -1
# 307      None  None  None         None          -1        0          -1
# 308      None  None  None         None          -1        0          -1
# 309      None  None  None         None          -1        0          -1
# 310      None  None  None         None          -1        0          -1
#
#     drawOrder  icon snippet healthCareDistrict  \
# 0        None  None            Varsinais-Suomi
# 1        None  None            Varsinais-Suomi
# 2        None  None                        HUS
# 3        None  None                        HUS
# 4        None  None                      Lappi
# ..        ...   ...     ...                ...
# 306      None  None                Päijät-Häme
# 307      None  None                      Vaasa
# 308      None  None            Etelä-Pohjanmaa
# 309      None  None            Etelä-Pohjanmaa
# 310      None  None                  Satakunta
#
#                                               geometry         district
# 0    POLYGON ((22.21005 60.59568, 22.21112 60.60216...  Varsinais-Suomi
# 1    POLYGON ((22.60238 60.92689, 22.61909 60.91401...  Varsinais-Suomi
# 2    MULTIPOLYGON (((24.83140 60.25406, 24.84191 60...              HUS
# 3    POLYGON ((25.15077 60.51673, 25.14175 60.50598...              HUS
# 4    POLYGON ((23.54049 67.46104, 23.53932 67.46102...            Lappi
# ..                                                 ...              ...
# 306  POLYGON ((26.23445 61.13000, 26.16662 61.13830...      Päijät-Häme
# 307  MULTIPOLYGON (((21.64785 62.01958, 21.52401 62...            Vaasa
# 308  POLYGON ((24.30094 62.98835, 24.25858 62.98575...  Etelä-Pohjanmaa
# 309  POLYGON ((23.27892 62.77471, 23.23131 62.78261...  Etelä-Pohjanmaa
# 310  POLYGON ((22.37369 62.14245, 22.45043 62.19846...        Satakunta
#
# [311 rows x 15 columns]

# %%
df = gpd.read_file('municipalities.json')

# %%
# create the plot
fig, ax = plt.subplots(figsize = (12,8))

# plot the data using a quantile map of the new ALAND values
df.dissolve(by='district').plot(edgecolor = "black",
                 scheme='quantiles', cmap='YlOrRd', ax=ax, 
                 legend = True)

# Set plot axis to equal ratio
ax.set_axis_off()
plt.axis('equal');

# %%
df.dissolve(by='district').to_file('../src/sairaanhoitopiirit_geo.json', driver="GeoJSON")
